# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.random.randint(1,20,15)
x
# Out:
# array([10, 19, 18, 18, 13, 18,  8,  4,  4,  6, 15,  3,  4,  5,  4])

# %%
b=x.reshape(3,5)
b
# Out:
# array([[10, 19, 18, 18, 13],
#        [18,  8,  4,  4,  6],
#        [15,  3,  4,  5,  4]])

# %%
c = np.where(b == [
   [i]
   for i in np.amax(b, axis = 1)
], 0, b)
c
# Out:
# array([[10,  0, 18, 18, 13],
#        [ 0,  8,  4,  4,  6],
#        [ 0,  3,  4,  5,  4]])

# %%
df = pd.read_csv("data.csv")
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
df.isnull()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0       False  False     False     False
# 1       False  False     False     False
# 2       False  False     False     False
# 3       False  False     False     False
# 4       False  False     False     False
# ..        ...    ...       ...       ...
# 164     False  False     False     False
# 165     False  False     False     False
# 166     False  False     False     False
# 167     False  False     False     False
# 168     False  False     False     False
#
# [169 rows x 4 columns]

# %%
df.isnull()
#calculating means of collumns
col1=df['Duration'].mean();
col2=df['Pulse'].mean();
col3=df['Maxpulse'].mean();
col4=df['Calories'].mean();
df['Duration'].fillna(value=col1,inplace=True);
df['Pulse'].fillna(value=col2,inplace=True);
df['Maxpulse'].fillna(value=col3,inplace=True);
df['Calories'].fillna(value=col4,inplace=True);
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.groupby('Duration').count()
# Out:
#           Pulse  Maxpulse  Calories
# Duration
# 15            2         2         2
# 20            9         9         9
# 25            1         1         1
# 30           16        16        16
# 45           35        35        35
# 60           79        79        79
# 75            2         2         2
# 80            1         1         1
# 90            8         8         8
# 120           3         3         3
# 150           4         4         4
# 160           2         2         2
# 180           3         3         3
# 210           2         2         2
# 270           1         1         1
# 300           1         1         1

# %%
df.groupby('Duration').mean()
# Out:
#                Pulse    Maxpulse     Calories
# Duration
# 15        102.000000  119.500000    87.350000
# 20        125.000000  146.000000   151.600000
# 25        152.000000  168.000000   244.200000
# 30        109.812500  137.000000   192.125000
# 45        107.485714  133.228571   279.096585
# 60        106.126582  132.860759   341.046465
# 75        122.500000  150.000000   325.400000
# 80        123.000000  146.000000   643.100000
# 90         93.750000  116.375000   541.800000
# 120       100.000000  139.000000   666.833333
# 150       101.500000  130.250000   939.400000
# 160       109.500000  136.000000   943.700000
# 180        93.666667  125.666667   733.600000
# 210       122.500000  172.000000  1618.200000
# 270       100.000000  131.000000  1729.000000
# 300       108.000000  143.000000  1500.200000

# %%
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.groupby('Pulse').max()
# Out:
#        Duration  Maxpulse     Calories
# Pulse
# 80           30       120   240.900000
# 83           20       107    50.300000
# 85           30       120   250.400000
# 90          180       130   800.400000
# 92           60       118   243.000000
# 93           90       128   604.100000
# 95           45       130   270.000000
# 97          150       131  1115.000000
# 98           90       126   563.200000
# 99           90       125   466.400000
# 100         270       157  1729.000000
# 101         180       127   600.100000
# 102          60       136   380.300000
# 103          60       147   375.790244
# 104          60       134   379.300000
# 105         150       140   873.400000
# 106          60       136   345.300000
# 107         150       138   816.000000
# 108         300       160  1500.200000
# 109         160       175   853.000000
# 110         160       150  1034.400000
# 111          60       151   400.000000
# 112          60       146   361.900000
# ...

# %%
df.groupby('Pulse').min()
# Out:
#        Duration  Maxpulse  Calories
# Pulse
# 80           15       100      50.5
# 83           20       107      50.3
# 85           30       120     250.4
# 90           30       100      86.2
# 92           30       108      92.7
# 93           30       113     124.0
# 95           20       112      77.7
# 97           45       122     243.0
# 98           60       120     215.2
# 99           60       119     273.0
# 100          45       119     100.7
# 101          60       124     299.0
# 102          45       124     234.0
# 103          30       123     151.1
# 104          45       129     253.3
# 105          45       125     246.0
# 106          20       126     110.4
# 107          45       124     275.0
# 108          45       129     298.0
# 109          30       127     188.2
# 110          20       130     131.4
# 111          45       131     300.0
# 112          30       137     193.9
# 113          45       138     308.0
# 114          45       140     304.0
# ...

# %%
df.loc[(df['Calories'] >= 500) & (df['Calories'] <= 1000)]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 51         80    123       146     643.1
# 62        160    109       135     853.0
# 65        180     90       130     800.4
# 66        150    105       135     873.4
# 67        150    107       130     816.0
# 72         90    100       127     700.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 78        120    100       130     500.4
# 83        120    100       130     500.0
# 90        180    101       127     600.1
# 99         90     93       124     604.1
# 101        90     90       110     500.0
# 102        90     90       100     500.0
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
df.loc[(df['Calories'] > 500) & (df['Pulse'] < 100)]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 65        180     90       130     800.4
# 70        150     97       129    1115.0
# 73        150     97       127     953.2
# 75         90     98       125     563.2
# 99         90     93       124     604.1
# 103        90     90       100     500.4
# 106       180     90       120     800.3
# 108        90     90       120     500.3

# %%
df_modified = df.loc[:, df.columns != 'Maxpulse']
df_modified
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %%
df=df.drop('Maxpulse', axis=1)
df
# Out:
#      Duration  Pulse  Calories
# 0          60    110     409.1
# 1          60    117     479.0
# 2          60    103     340.0
# 3          45    109     282.4
# 4          45    117     406.0
# ..        ...    ...       ...
# 164        60    105     290.8
# 165        60    110     300.0
# 166        60    115     310.2
# 167        75    120     320.4
# 168        75    125     330.4
#
# [169 rows x 3 columns]

# %%
df = df.astype({'Calories':'int'})
print(df.dtypes)
# Out:
# Duration    int64
# Pulse       int64
# Calories    int64
# dtype: object

# %%
ax1 = df.plot.scatter(x='Duration', y='Calories')
ax1
# Out:
# <AxesSubplot:xlabel='Duration', ylabel='Calories'>

# %%
values= [22.2, 17.6, 8.8, 8, 7.7, 6.7];
languages=['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++'];
fig1, ax1 = plt.subplots()
ax1.pie(values, labels=languages, autopct='%1.1f%%',
shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
